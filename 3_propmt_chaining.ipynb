# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model="gemini-3.5-flash")

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': [{'type': 'text', 'text': 'Here is a comprehensive and highly detailed outline for a blog post on the **Rise of AI in India**. This outline is structured to be engaging, SEO-friendly, and informative, moving from foundational context to real-world impact, challenges, and future outlook.\n\n---\n\n# Blog Title Ideas:\n1. *The Silicon Renaissance: How India is Becoming the Next AI Superpower*\n2. *From Back-Office to AI Hub: The Rise of Artificial Intelligence in India*\n3. *Bytes, Brains, and Billions: Charting India’s AI Revolution*\n\n---\n\n## **I. Introduction**\n*   **Hook:** Start with a compelling hook—either a statistic (e.g., India’s projected AI market size by 2030) or a real-world scenario (e.g., a farmer in rural Maharashtra using an AI voice-bot to check soil health in his local dialect).\n*   **The Narrative Shift:** Explain how India is transitioning from being the "world’s IT helpdesk" to a "global co-creator of AI."\n*   **Thesis Statement:** Powered by massive digital public infrastructure, a vast developer talent pool, and supportive government policies, India is uniquely positioned to lead the next wave of the global AI revolution.\n\n## **II. The Catalysts: Why India is Ripe for the AI Boom**\n*   **The Jio Effect & Digital Public Infrastructure (DPI):** \n    *   Explosion of cheap mobile data.\n    *   The foundation laid by UPI, Aadhaar, and India Stack, providing massive, structured datasets.\n*   **The Talent Goldmine:**\n    *   India has the world’s largest developer population (over 5 million).\n    *   The surge of AI, Machine Learning (ML), and Data Science courses in Indian universities (IITs, IIITs).\n*   **"Jugaad" Meets Deep Tech (Frugal Innovation):** \n    *   India\'s knack for building highly efficient, cost-effective tech solutions (e.g., building LLMs at a fraction of Silicon Valley costs).\n\n## **III. Sectoral Impact: How AI is Transforming Bharat**\n*   **1. Healthcare: Democratizing Access**\n    *   *AI in Diagnostics:* Using AI to screen for tuberculosis, diabetic retinopathy, and cancers in remote villages.\n    *   *Example:* Startups like Qure.ai using AI to read X-rays in minutes.\n*   **2. Agriculture (AgriTech): Empowring Farmers**\n    *   Predictive analytics for crop yields, weather forecasting, and pest control.\n    *   *Example:* Government and startup initiatives using drones and AI to optimize fertilizer usage.\n*   **3. Education (EdTech): Hyper-Personalization**\n    *   AI tutors offering personalized learning paths for students in regional languages.\n    *   Bridging the teacher-student ratio gap in public schools.\n*   **4. FinTech: Financial Inclusion**\n    *   AI-driven credit scoring for the "unbanked" population who lack traditional credit histories.\n    *   Real-time fraud detection on UPI transactions.\n*   **5. Governance & Public Services (GovTech)**\n    *   *Bhashini AI:* The translation tool breaking language barriers, allowing citizens to access government services in 22 official Indian languages using voice commands.\n\n## **IV. The Indian AI Startup & Corporate Landscape**\n*   **The Rise of Indic LLMs (Large Language Models):**\n    *   Why Western LLMs don\'t work for India (linguistic diversity, cultural context).\n    *   *Key Players:* Krutrim (Ola), Sarvam AI, Hanooman, and Tamil LLaMA.\n*   **SaaS and Enterprise Shift:**\n    *   How legacy IT giants (TCS, Infosys, Wipro) are retraining hundreds of thousands of employees in AI.\n    *   Indian SaaS companies (Zoho, Freshworks) integrating generative AI into global products.\n*   **Inflow of Capital:** A look at venture capital trends shifting from traditional e-commerce to deep-tech and AI startups.\n\n## **V. The Government\'s Vision: "AI for All"**\n*   **The IndiaAI Mission:**\n    *   The cabinet’s ₹10,372 crore ($1.25 billion) allocation to build sovereign AI infrastructure.\n    *   Setting up AI supercomputing centers (GPU availability for ...

# %%
print(final_state['outline'])
# Out:
# [{'type': 'text', 'text': 'Here is a comprehensive and highly detailed outline for a blog post on the **Rise of AI in India**. This outline is structured to be engaging, SEO-friendly, and informative, moving from foundational context to real-world impact, challenges, and future outlook.\n\n---\n\n# Blog Title Ideas:\n1. *The Silicon Renaissance: How India is Becoming the Next AI Superpower*\n2. *From Back-Office to AI Hub: The Rise of Artificial Intelligence in India*\n3. *Bytes, Brains, and Billions: Charting India’s AI Revolution*\n\n---\n\n## **I. Introduction**\n*   **Hook:** Start with a compelling hook—either a statistic (e.g., India’s projected AI market size by 2030) or a real-world scenario (e.g., a farmer in rural Maharashtra using an AI voice-bot to check soil health in his local dialect).\n*   **The Narrative Shift:** Explain how India is transitioning from being the "world’s IT helpdesk" to a "global co-creator of AI."\n*   **Thesis Statement:** Powered by massive digital public infrastructure, a vast developer talent pool, and supportive government policies, India is uniquely positioned to lead the next wave of the global AI revolution.\n\n## **II. The Catalysts: Why India is Ripe for the AI Boom**\n*   **The Jio Effect & Digital Public Infrastructure (DPI):** \n    *   Explosion of cheap mobile data.\n    *   The foundation laid by UPI, Aadhaar, and India Stack, providing massive, structured datasets.\n*   **The Talent Goldmine:**\n    *   India has the world’s largest developer population (over 5 million).\n    *   The surge of AI, Machine Learning (ML), and Data Science courses in Indian universities (IITs, IIITs).\n*   **"Jugaad" Meets Deep Tech (Frugal Innovation):** \n    *   India\'s knack for building highly efficient, cost-effective tech solutions (e.g., building LLMs at a fraction of Silicon Valley costs).\n\n## **III. Sectoral Impact: How AI is Transforming Bharat**\n*   **1. Healthcare: Democratizing Access**\n    *   *AI in Diagnostics:* Using AI to screen for tuberculosis, diabetic retinopathy, and cancers in remote villages.\n    *   *Example:* Startups like Qure.ai using AI to read X-rays in minutes.\n*   **2. Agriculture (AgriTech): Empowring Farmers**\n    *   Predictive analytics for crop yields, weather forecasting, and pest control.\n    *   *Example:* Government and startup initiatives using drones and AI to optimize fertilizer usage.\n*   **3. Education (EdTech): Hyper-Personalization**\n    *   AI tutors offering personalized learning paths for students in regional languages.\n    *   Bridging the teacher-student ratio gap in public schools.\n*   **4. FinTech: Financial Inclusion**\n    *   AI-driven credit scoring for the "unbanked" population who lack traditional credit histories.\n    *   Real-time fraud detection on UPI transactions.\n*   **5. Governance & Public Services (GovTech)**\n    *   *Bhashini AI:* The translation tool breaking language barriers, allowing citizens to access government services in 22 official Indian languages using voice commands.\n\n## **IV. The Indian AI Startup & Corporate Landscape**\n*   **The Rise of Indic LLMs (Large Language Models):**\n    *   Why Western LLMs don\'t work for India (linguistic diversity, cultural context).\n    *   *Key Players:* Krutrim (Ola), Sarvam AI, Hanooman, and Tamil LLaMA.\n*   **SaaS and Enterprise Shift:**\n    *   How legacy IT giants (TCS, Infosys, Wipro) are retraining hundreds of thousands of employees in AI.\n    *   Indian SaaS companies (Zoho, Freshworks) integrating generative AI into global products.\n*   **Inflow of Capital:** A look at venture capital trends shifting from traditional e-commerce to deep-tech and AI startups.\n\n## **V. The Government\'s Vision: "AI for All"**\n*   **The IndiaAI Mission:**\n    *   The cabinet’s ₹10,372 crore ($1.25 billion) allocation to build sovereign AI infrastructure.\n    *   Setting up AI supercomputing centers (GPU availability for startups).\n*   **NITI Aayog’s National Str ...

# %%
print(final_state['content'])
# Out:
# [{'type': 'text', 'text': '# The Silicon Renaissance: How India is Becoming the Next AI Superpower\n\nImagine a small farm in rural Maharashtra, miles away from any major city. Ramrao, a third-generation farmer, notices a strange yellowing on his cotton leaves. Instead of waiting weeks for an agricultural expert to visit, he pulls out his basic smartphone, opens a WhatsApp-integrated voice-bot, and asks a question in his local Marathi dialect. \n\nWithin seconds, an AI engine analyzes his voice input, cross-references satellite imagery of his plot, diagnoses a pest infestation, and speaks back to him in Marathi, recommending a precise, low-cost organic pesticide. \n\nThis isn\'t a futuristic sci-fi concept; it is happening today across rural India. \n\n```\n   THE INDIA AI MARKET TRAJECTORY\n   ┌────────────────────────────────────────────────────────┐\n   │ 2023: ~$4-5 Billion (Early Adoption Phase)             │\n   ├────────────────────────────────────────────────────────┤\n   │ 2027: Projecting ~$17 Billion                          │\n   ├────────────────────────────────────────────────────────┤\n   │ 2030: Estimated to hit $22+ Billion                    │\n   └────────────────────────────────────────────────────────┘\n   Source: NASSCOM / BCG Reports\n```\n\nFor decades, India was celebrated—and sometimes pigeonholed—as the "world’s back-office." It was the land of IT helpdesks, software maintenance, and business process outsourcing (BPO). However, a profound narrative shift is underway. India is rapidly transitioning from a software services exporter to a **global co-creator and leader of Artificial Intelligence**. \n\nPowered by a massive digital public infrastructure, the world’s largest developer talent pool, and supportive government policy, India is uniquely positioned to lead the next wave of the global AI revolution.\n\n---\n\n## II. The Catalysts: Why India is Ripe for the AI Boom\n\nAn AI revolution does not happen in a vacuum. It requires three critical ingredients: abundant data, a massive technical workforce, and a culture of agile problem-solving. India possesses all three in abundance.\n\n```\n                  ┌─────────────────────────────┐\n                  │   THE TRIAD OF INDIAN AI    │\n                  └──────────────┬──────────────┘\n                                 │\n         ┌───────────────────────┼───────────────────────┐\n         ▼                       ▼                       ▼\n┌──────────────────┐   ┌──────────────────┐   ┌──────────────────┐\n│ THE JIO EFFECT & │   │   THE TALENT     │   │  FRUGAL DEEPTECH │\n│    DPI ENGINE    │   │    GOLDMINE      │   │   ("JUGAAD")     │\n├──────────────────┤   ├──────────────────┤   ├──────────────────┤\n│ Ubiquitous data; │   │ 5 Million+ dev   │   │ High-performance │\n│ Aadhaar, UPI &   │   │ ecosystem; heavy │   │ models built at  │\n│ transaction logs │   │ academic pivot.  │   │ minimal expense. │\n└──────────────────┘   └──────────────────┘   └──────────────────┘\n```\n\n### 1. The Jio Effect & Digital Public Infrastructure (DPI)\nIn 2016, the launch of Reliance Jio democratized mobile internet, triggering an explosion of ultra-cheap cellular data. Today, an average Indian consumer consumes over 24 GB of data per month—one of the highest consumption rates globally. \n\nSimultaneously, India built its **Digital Public Infrastructure (DPI)**, often called the **India Stack**. Built on three pillars:\n*   **Identity (Aadhaar):** Providing biometric digital identities to over 1.3 billion citizens.\n*   **Payments (UPI):** Facilitating billions of instant, paperless transactions every month.\n*   **Data Sharing (Account Aggregator):** Enabling secure, consent-based financial data exchanges.\n\nThis structural foundation has yielded massive, clean, structured, and real-time datasets. While Western AI companies are running out of public internet data to train their models, India is sitting on a goldmine of transaction-level, operational data.\n\n# ...
